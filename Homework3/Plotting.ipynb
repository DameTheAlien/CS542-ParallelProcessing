# %% [markdown]
# # Plot of runtimes for question 2

# %%
# importing the required module
import matplotlib.pyplot as plt
import numpy as np
from google.colab import files

# %%
# Plot the runtimes 
nvals = [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072, 26144, 524288]
myrun = [0.000024, 0.000019, 0.000017, 0.000013, 0.000017, 0.000039, 0.000025, 0.000017, 0.000015, 0.000020, 0.000021, 0.000046, 0.000077, 0.000059, 0.000099, 0.000179, 0.000352, 0.000685, 0.001694, 0.006740]

plt.plot(nvals, myrun)
plt.xlabel('Size of message (n)')
plt.ylabel('Runtime (sec)')
plt.title('HW3 - Single Ping Pong Runtimes')

#plt.savefig("PCA_variance.png", bbox_inches='tight', dpi=300)
#files.download("PCA_variance.png")
# Out:
# Text(0.5, 1.0, 'HW3 - Single Ping Pong Runtimes')

# %%
# Plot the runtimes
nvals = [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072, 26144, 524288]
enhancedmyrun = [0.000005, 0.000020, 0.000018, 0.000016, 0.000022, 0.000018, 0.000018, 0.000016, 0.000013, 0.000014, 0.000010, 0.000015, 0.000027, 0.000046, 0.000088, 0.000171, 0.000345, 0.000728, 0.001410, 0.002940]

plt.plot(nvals, enhancedmyrun)
plt.xlabel('Size of message (n)')
plt.ylabel('Runtime (sec)')
plt.title('HW3 - Synced Ping Pong Runtimes')

#plt.savefig("PCA_variance.png", bbox_inches='tight', dpi=300)
#files.download("PCA_variance.png")

# %%
# Plot the runtimes
nvals = [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072, 26144, 524288]
myrun = [0.000024, 0.000019, 0.000017, 0.000013, 0.000017, 0.000039, 0.000025, 0.000017, 0.000015, 0.000020, 0.000021, 0.000046, 0.000077, 0.000059, 0.000099, 0.000179, 0.000352, 0.000685, 0.001694, 0.006740]
enhancedmyrun = [0.000005, 0.000020, 0.000018, 0.000016, 0.000022, 0.000018, 0.000018, 0.000016, 0.000013, 0.000014, 0.000010, 0.000015, 0.000027, 0.000046, 0.000088, 0.000171, 0.000345, 0.000728, 0.001410, 0.002940]

plt.plot(nvals, myrun)
plt.plot(nvals, enhancedmyrun)
plt.xlabel('Size of message (n)')
plt.ylabel('Runtime (sec)')
plt.legend(['Single Ping Pong', 'Synced Ping Pong'])
plt.title('HW3 - Sync vs Single Ping Pong Runtimes')

#plt.savefig("PCA_variance.png", bbox_inches='tight', dpi=300)
#files.download("PCA_variance.png")

# %%
# Plot the runtimes
nvals = [1, 8, 16, 32]
parapi = [0.058707, 0.010831, 0.030930, 0.004376]

plt.plot(nvals, parapi)
plt.xlabel('Number of processes used')
plt.ylabel('Runtime (sec)')
#plt.legend(['Single Ping Pong', 'Synced Ping Pong'])
plt.title('HW3 - Parallel Pi Runtimes')

#plt.savefig("PCA_variance.png", bbox_inches='tight', dpi=300)
#files.download("PCA_variance.png")

# %%
# Plot the runtimes
nvals = [1, 16, 64]
simpleruns = [1.040234, 1.031207, 1.220648]
foxruns = [0.1325184, 0.1019896, 0.001773277]
cannonruns = [0.05327069, 0.02707138, 0.0003360830]

#plt.plot(nvals, simpleruns)
plt.plot(nvals, foxruns)
plt.plot(nvals, cannonruns)
plt.xlabel('Number of processes used')
plt.ylabel('Runtime (sec)')
plt.legend(['Fox Algorithm', 'Cannon Algorithm'])
plt.title('HW3 - MatMat Multiplication Methods Runtimes')

plt.savefig("PCA_variance.png", bbox_inches='tight', dpi=300)
files.download("PCA_variance.png")#

# %% [markdown]
# # Save fig copy and paste

# %%
#plt.savefig("PCA_variance.png", bbox_inches='tight', dpi=200)
#files.download("PCA_variance.png")

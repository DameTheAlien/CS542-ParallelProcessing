# %% [markdown]
# # Plot of runtimes for question 2

# %%
# importing the required module
import matplotlib.pyplot as plt
from google.colab import files

# %%
# Plot the runtimes for number 2 here...
nvals = [25, 100, 10000]
streamrun = [0.000001, 0.000001, 0.000009]
streamcacherun = [0.0000001, 0.000001, 0.000006]
myrun = [0.000004, 0.000043, 0.2866140008]

plt.plot(nvals, streamrun)
plt.plot(nvals, streamcacherun)
#plt.plot(nvals, myrun)
plt.xlabel('n')
plt.ylabel('Runtime (sec)')
plt.title('HW2 - 2d Runtime Graph (STREAM)')
#plt.show()
plt.savefig("PCA_variance.png", bbox_inches='tight', dpi=300)
files.download("PCA_variance.png")

# %% [markdown]
# # Save fig copy and paste

# %%
#plt.savefig("PCA_variance.png", bbox_inches='tight', dpi=200)
#files.download("PCA_variance.png")
